# %%
from pyecharts import options as opts
from pyecharts.charts import Geo
from pyecharts.charts import Map
from pyecharts.faker import Faker
from pyecharts.globals import ChartType

# %%
help(ChartType)
# Out:
# Help on class _ChartType in module pyecharts.globals:
#
# class _ChartType(builtins.object)
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  BAR = 'bar'
#  |
#  |  BAR3D = 'bar3D'
#  |
#  |  BOXPLOT = 'boxplot'
#  |
#  |  CUSTOM = 'custom'
#  |
#  |  EFFECT_SCATTER = 'effectScatter'
#  |
#  |  FUNNEL = 'funnel'
#  |
#  |  GAUGE = 'gauge'
#  |
#  |  GEO = 'geo'
#  |
#  |  GRAPH = 'graph'
#  |
#  |  HEATMAP = 'heatmap'
#  |
#  |  KLINE = 'candlestick'
#  |
#  |  LINE = 'line'
#  |
#  |  LINE3D = 'line3D'
#  |
#  |  LINES = 'lines'
#  |
#  |  LINES3D = 'lines3D'
#  |
#  |  LIQUID = 'liquidFill'
#  |
#  |  MAP = 'map'
#  |
#  |  MAP3D = 'map3D'
#  |
#  |  PARALLEL = 'parallel'
#  |
# ...

# %%
help(Faker)
# Out:
# Help on _Faker in module pyecharts.faker object:
#
# class _Faker(builtins.object)
#  |  Methods defined here:
#  |
#  |  choose(self) -> list
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  img_path(path: str, prefix: str = 'images') -> str
#  |
#  |  rand_color() -> str
#  |
#  |  values(start: int = 20, end: int = 150) -> list
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  animal = ['河马', '蟒蛇', '老虎', '大象', '兔子', '熊猫', '狮子']
#  |
#  |  cars = ['宝马', '法拉利', '奔驰', '奥迪', '大众', '丰田', '特斯拉']
#  |
# ...

# %%
import pandas as pd
df = pd.read_excel('1.21微博数据.xlsx')
df[:3]
# Out:
#   来源媒体       媒体名称       微博uid  频道  \
# 0    微博      需要抢救  6090611988 NaN
# 1    微博  无用的拉普拉斯妖  6042825462 NaN
# 2    微博     小姐姐文静  5629347513 NaN
#
#                                                   标题   摘要 情感属性      发文时间  \
# 0  武汉肺炎武汉肺炎武汉肺炎 可不就是武汉为源头的肺炎吗//@无用的拉普拉斯妖:回复@Jook-...  NaN   负面  12:50:28
# 1  回复@Jook-Not-alone:武汉肺炎武汉肺炎武汉肺炎武汉肺炎武汉肺炎武汉肺炎武汉肺炎...  NaN   中性  12:47:44
# 2         #长春发现1例疑似新型肺炎病例##肺炎##吉林肺炎##长春发现疑似新型肺炎病例# ​  NaN   正面  23:53:22
#
#                                                   链接   文章提及城市  ...  \
# 0  http://weibo.com/6090611988/IquUOyeYr?refer_fl...  ["武汉市"]  ...
# 1  http://weibo.com/6042825462/IquTIiLC2?refer_fl...  ["武汉市"]  ...
# 2  http://weibo.com/5629347513/IqzfTroUH?refer_fl...  ["长春市"]  ...
#
#                           news_uuid                          sim_hash  \
# 0  9a66062574f5051b1cfebcf80bd32fdc  827e98cc45e515937a633b4272e434f1
# 1  9d9268de2c6a8d3b8e8a587a27c76a24  c277390276d7091e72afb3a2fd2870f9
# ...

# %%
c = (
    Geo()
    .add_schema(maptype="china")
    .add("geo", [list(z) for z in zip(['泰安', '酒泉', '宝鸡'], [33, 99, 10])])
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-基本示例")
    )
    .render("geo_base.html")
)

c.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="f945dd05893c40f99eb5a01698445c39" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_f945dd05893c40f99eb5a01698445c39 = echarts.init(
#                     document.getElementById('f945dd05893c40f99eb5a01698445c39'), 'white', {renderer: 'canvas'});
#                 var option_f945dd05893c40f99eb5a01698445c39 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %% [markdown]
# ## 省份地图

# %%
geo = (
    Geo()
    .add_schema(maptype="china")
    .add(
        "geo",
        [list(z) for z in zip(Faker.provinces, Faker.values())],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(),
        title_opts=opts.TitleOpts(title="省份热力图"),
    )
    #.render("geo-heatmap.html") # save the html
)

# %%
geo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china':'https://assets.pyecharts.org/assets/maps/china'
#         }
#     });
# </script>
#
#         <div id="dd8c4439325747388e93b1deada3df6f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china'], function(echarts) {
#                 var chart_dd8c4439325747388e93b1deada3df6f = echarts.init(
#                     document.getElementById('dd8c4439325747388e93b1deada3df6f'), 'white', {renderer: 'canvas'});
#                 var option_dd8c4439325747388e93b1deada3df6f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
[list(z) for z in zip(Faker.guangdong_city, Faker.values())]
# Out:
# [['汕头市', 116],
#  ['汕尾市', 47],
#  ['揭阳市', 25],
#  ['阳江市', 21],
#  ['肇庆市', 111],
#  ['广州市', 95],
#  ['惠州市', 141]]

# %%
dmap = (
    Map()
    .add(
        "焦虑",
        [list(z) for z in zip(['泰安', '酒泉', '宝鸡'], [33, 99, 10])], 
        "china-cities",
        label_opts=opts.LabelOpts(is_show=False),
    )
    .set_global_opts(
        title_opts=opts.TitleOpts(title="疫情焦虑地图"),
        visualmap_opts=opts.VisualMapOpts(),
    )
    #.render("map_china_cities.html")
)

dmap.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', 'china-cities':'https://assets.pyecharts.org/assets/maps/china-cities'
#         }
#     });
# </script>
#
#         <div id="7052242341354844a77ebeaa2fc1ac68" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', 'china-cities'], function(echarts) {
#                 var chart_7052242341354844a77ebeaa2fc1ac68 = echarts.init(
#                     document.getElementById('7052242341354844a77ebeaa2fc1ac68'), 'white', {renderer: 'canvas'});
#                 var option_7052242341354844a77ebeaa2fc1ac68 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
# ...

# %%
ggeo = (
    Geo()
    .add_schema(maptype="广东")
    .add(
        "geo",
        [list(z) for z in zip(Faker.guangdong_city, Faker.values())],
        type_=ChartType.HEATMAP,
    )
    .set_series_opts(label_opts=opts.LabelOpts(is_show=False))
    .set_global_opts(
        visualmap_opts=opts.VisualMapOpts(), title_opts=opts.TitleOpts(title="Geo-广东地图")
    )
    #.render("geo_guangdong.html")
)

ggeo.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min', '广东':'https://assets.pyecharts.org/assets/maps/guangdong'
#         }
#     });
# </script>
#
#         <div id="da7be2d4cf3149f7950d77bcdaeed77d" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts', '广东'], function(echarts) {
#                 var chart_da7be2d4cf3149f7950d77bcdaeed77d = echarts.init(
#                     document.getElementById('da7be2d4cf3149f7950d77bcdaeed77d'), 'white', {renderer: 'canvas'});
#                 var option_da7be2d4cf3149f7950d77bcdaeed77d = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
# ...

# %%
from pyecharts import options as opts
from pyecharts.charts import Bar
from pyecharts.commons.utils import JsCode
from pyecharts.globals import ThemeType

list2 = [
    {"value": 12, "percent": 12 / (12 + 3)},
    {"value": 23, "percent": 23 / (23 + 21)},
    {"value": 33, "percent": 33 / (33 + 5)},
    {"value": 3, "percent": 3 / (3 + 52)},
    {"value": 33, "percent": 33 / (33 + 43)},
]

list3 = [
    {"value": 3, "percent": 3 / (12 + 3)},
    {"value": 21, "percent": 21 / (23 + 21)},
    {"value": 5, "percent": 5 / (33 + 5)},
    {"value": 52, "percent": 52 / (3 + 52)},
    {"value": 43, "percent": 43 / (33 + 43)},
]

c = (
    Bar(init_opts=opts.InitOpts(theme=ThemeType.LIGHT))
    .add_xaxis([1, 2, 3, 4, 5])
    .add_yaxis("product1", list2, stack="stack1", category_gap="50%")
    .add_yaxis("product2", list3, stack="stack1", category_gap="50%")
    .set_series_opts(
        label_opts=opts.LabelOpts(
            position="right",
            formatter=JsCode(
                "function(x){return Number(x.data.percent * 100).toFixed() + '%';}"
            ),
        )
    )
    .render("stack_bar_percent.html")
)

# %%
import pyecharts.options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

c = (
    Line()
    .add_xaxis(Faker.choose())
    .add_yaxis("商家A", Faker.values())
    .add_yaxis("商家B", Faker.values())
    .set_global_opts(title_opts=opts.TitleOpts(title="Line-基本示例"))
    .render("line_base.html")
)

# %%
c
# Out:
# '/Users/datalab/github/datascience/vis/line_base.html'

# %%
from IPython.display import display
from IPython.display import HTML
import IPython.core.display as di
di.display_html('<script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>', raw=True)
CSS = """#notebook div.output_subarea {max-width:100%;}""" #changes output_subarea width to 100% (from 100% - 14ex)
HTML('<style>{}</style>'.format(CSS))
# Out:
# <script>jQuery(function() {if (jQuery("body.notebook_app").length == 0) { jQuery(".input_area").toggle(); jQuery(".prompt").toggle();}});</script>
# <style>#notebook div.output_subarea {max-width:100%;}</style>

# %%
di.display_html(c)

# %%
help(HTML)
# Out:
# Help on class HTML in module IPython.core.display:
#
# class HTML(TextDisplayObject)
#  |  HTML(data=None, url=None, filename=None, metadata=None)
#  |
#  |  Validate that display data is text
#  |
#  |  Method resolution order:
#  |      HTML
#  |      TextDisplayObject
#  |      DisplayObject
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __html__(self)
#  |      This method exists to inform other HTML-using modules (e.g. Markupsafe,
#  |      htmltag, etc) that this object is HTML and does not need things like
#  |      special characters (<>&) escaped.
#  |
#  |  __init__(self, data=None, url=None, filename=None, metadata=None)
#  |      Create a display object given raw data.
#  |
#  |      When this object is returned by an expression or passed to the
#  |      display function, it will result in the data being displayed
#  |      in the frontend. The MIME type of the data should match the
# ...

# %%
from IPython.display import HTML

HTML(filename=c)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <meta charset="UTF-8">
#     <title>Awesome-pyecharts</title>
#             <script type="text/javascript" src="https://assets.pyecharts.org/assets/echarts.min.js"></script>
#
# </head>
# <body>
#     <div id="6bec135d28ad4820a61a008229a685e5" class="chart-container" style="width:900px; height:500px;"></div>
#     <script>
#         var chart_6bec135d28ad4820a61a008229a685e5 = echarts.init(
#             document.getElementById('6bec135d28ad4820a61a008229a685e5'), 'white', {renderer: 'canvas'});
#         var option_6bec135d28ad4820a61a008229a685e5 = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
# ...
