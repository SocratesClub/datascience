# %% [markdown]
# ---
# ---
#
#
# # Bit by Bit: Social Research in the Digital Age
#
#
# ---
# ---
#
# CHAPTER 1  INTRODUCTION
#
# Cheng-Jun Wang
#
# wangchengjun@nju.edu.cn

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Matthew J. Salganik (2018) Bit by Bit: Social Research in the Digital Age. Princeton University Press

# %% [markdown]
# - PREFACE
# - **CHAPTER 1 • INTRODUCTION**
# - CHAPTER 2 • OBSERVING BEHAVIOR
# - CHAPTER 3 • ASKING QUESTIONS
# - CHAPTER 4 • RUNNING EXPERIMENTS
# - CHAPTER 5 • CREATING MASS COLLABORATION
# - CHAPTER 6 • ETHICS

# %% [markdown]
# ## 1.1 An ink blot
#
# In the summer of 2009, mobile phones were ringing all across Rwanda. In addition to the millions of calls from family, friends, and business associates, about 1,000 Rwandans received a call from Joshua Blumenstock and his colleagues. These researchers were studying wealth and poverty by conducting a survey of a random sample of people from a database of 1.5 million customers of Rwanda’s largest mobile phone provider.
#
# (Blumenstock, Cadamuro, and On 2015).

# %% [markdown]
# In addition to the survey data, Blumenstock and colleagues also had the complete call records for all 1.5 million people. Combining these two sources of data, they used the survey data to train a machine learning model to predict a person’s wealth based on their call records. Next, they used this model to estimate the wealth of all 1.5 million customers in the database.
#
# They also estimated the places of residence of all 1.5 million customers using the geographic information embedded in the call records. Putting all of this together—the estimated wealth and the estimated place of residence—they were able to produce high-resolution maps of the geographic distribution of wealth in Rwanda.
#
# (Blumenstock, Cadamuro, and On 2015).

# %% [markdown]
# ![image.png](attachment:image.png)
#
# Hermann Rorschach Test is a psyhological test allows investigate personality in detail and determine the disorder of the person's psychological state. This test is also known as the Rorschach Inkblot Test. Why such a strange name? The answer is simple! Testing on the spots (inkblots) of incomprehensible shape causes different associations, on the basis of which the person's mental state is determined.

# %% [markdown]
# This study is kind of like a Rorschach inkblot test: what people see depends on their background.
#
# - Many social scientists see a new measurement tool that can be used to test theories about economic development.
# - Many data scientists see a cool new machine learning problem. Many business people see a powerful approach for unlocking value in the big data that they have already collected.
# - Many privacy advocates see a scary reminder that we live in a time of mass surveillance.
# - Many policy makers see a way that new technology can help create a better world.
#
# In fact, this study is a window into the future of social research.

# %% [markdown]
# ## 1.2 Welcome to the digital age
#
# > The digital age is everywhere, it’s growing, and it changes what is possible for researchers.
#
# - Many things in your life that used to be analog are now digital.
#     - “Internet of Things”
# - Increasingly, these ubiquitous computers do more than just calculate:
#     - they also sense, store, and transmit information.

# %% [markdown]
# This ability to randomize on top of tracking means that online stores can constantly run randomized controlled experiments.
#
# This fully measured, fully randomizable world is not just happening online; it is increasingly happening everywhere.
#
# The “Internet of Things” means that behavior in the physical world will increasingly be captured by digital sensors.

# %% [markdown]
# When you think about social research in the digital age, you should not just think online, you should think everywhere.

# %% [markdown]
# In addition to enabling the measurement of behavior and randomization of treatments, the digital age has also created new ways for people to communicate.
#
# These new forms of communication allow researchers to run innovative surveys and to create mass collaboration with their colleagues and the general public.

# %% [markdown]
# A skeptic might point out that none of these capabilities are really new. But more is different.
#
# > If you can capture an image of a horse, then you have a photograph. And if you can capture 24 images of a horse per second, then you have a movie. Of course, a movie is just a bunch of photos, but only a die-hard skeptic would claim that photos and movies are the same.

# %% [markdown]
# We must combine the approaches of the past with the capabilities of the present and future.
# - The research of Joshua Blumenstock and colleagues was a mixture of traditional survey research with what some might call data science.

# %% [markdown]
# ## 1.3 Research design
#
# > Research design is about connecting questions and answers.

# %% [markdown]
# The best way to create this powerful hybrid is not to focus on abstract social theory or fancy machine learning.
# - Social scientists
# - Data scientists
# - The best place to start is research design.

# %% [markdown]
#  If you think of social research as the process of asking and answering questions about human behavior, then research design is the connective tissue; research design links questions and answers.
#
# Four approaches:
#
# - observing behavior
# - asking questions
# - running experiments
# - mass collaboration

# %% [markdown]
# ## 1.4 Themes of this book
# Two themes in the book are
# - (1) mixing readymades and custommades and
# - (2) ethics.

# %% [markdown]
# ![image.png](attachment:image.png)
#
# - Fountain by Marcel Duchamp
# - David by Michelangelo.
#
# Duchamp, Marcel | d(y)o͞oˈSHäN |
# (1887–1968), US artist; born in France. A leading figure of the Dada movement and originator of conceptual art, he invented “ready-mades,” mass-produced articles selected at random and displayed as works of art.

# %% [markdown]
# 现成品vs.订制品
#
# - Fountain is an example of a readymade, where an artist sees something that already exists in the world and then creatively repurposes it for art.
# - David is an example of art that was intentionally created; it is a custommade.
#
#
# Social research in the digital age will involve both readymades and custommades.

# %% [markdown]
# As you will see, some of the studies involve clever **repurposing of big data sources** that were originally created by companies and governments.
#
# Joshua Blumenstock and colleagues were part Duchamp and part Michelangelo: they repurposed the call records (a readymade), and they created their own survey data (a custommade).

# %% [markdown]
# A second theme that runs through this book is ethics.
# - Researchers—often in collaboration with companies and governments—have increasing power over the lives of participants.
#
# With an increase in power, there must also come an increase in responsibility.

# %% [markdown]
# ![discuss.gif](attachment:discuss.gif)
